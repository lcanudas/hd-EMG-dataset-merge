# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fs = 2048

# %%
file = open('./biceps/s7_e10_bb.bin',"rb")
x = np.fromfile(file, dtype='<d')
x = x.reshape(120,-1)
x = x.T

# %%
t = np.arange(x.shape[0])/fs

# %%
plt.plot(t,x[:,35])

# %%
2048*10
# Out:
# 20480
